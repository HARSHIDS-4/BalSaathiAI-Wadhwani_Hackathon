# %% [markdown]
# # BalSaathiAI - Har Baccha, Sahi Samay
#
# ### Shai for Shiksha Hackathon 2026 | Team Vibe Before Code
# Harshi Gupta | Akshita Tyagi | Ankita Rai

# %% [markdown]
# ## Executive Summary
#
# BalSaathiAI is an AI-powered early developmental screening platform for Anganwadi workers in rural India.
#
# ## Problem
# 13.7 million children in India live with developmental disabilities. The average age of diagnosis in rural India is **5-6 years**. The critical intervention window closes at **3 years**.
#
# ## Risk Classification
#
# | Risk Level | Meaning | Action |
# |---|---|---|
# | On Track | Development within normal range | Re-screen in 3 months |
# | Watch | Mild concern in one or more domains | Re-screen in 6 weeks |
# | Refer Now | Significant delay detected | Immediate specialist referral |
#
#
# ## Model Selected: Logistic Regression as it out performs Random Forest and XGBoost

# %% [markdown]
# ## Work Flow
#
# 1. Import Libraries
# 2. Data Source
# 3. Data Loading and Inspection
# 4. EDA(Exploratory Data Analysis)
# 5. Train Test Split
# 6. Data Pipeline
# 7. Model Selection
# 8. Feature Importance
# 9. Exporting Model

# %% [markdown]
# ## 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import (train_test_split,GridSearchCV) 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import (classification_report,confusion_matrix,roc_curve, auc)
from sklearn.preprocessing import (OrdinalEncoder,OneHotEncoder) 
from sklearn.feature_selection import SelectKBest,f_classif
from xgboost import XGBClassifier
import pickle

# %% [markdown]
# ## 2. Data Source and Overview
#
# > **Note:** A synthetic dataset was generated for this prototype due to absence of publicly available Indian pediatric developmental screening data. This is disclosed in accordance with responsible AI practices.
#
# Dataset Characteristics
#
# - Developmental screening records
# - Age range: 12–72 months
# - Domains covered:
#   - Speech and Language
#   - Motor Skills
#   - Social Interaction
#   - Cognitive Development
#
# Target Variable
#
# - Risk_Level

# %% [markdown]
# ## 3. Dataset Loading and Inspection

# %%
children=pd.read_csv("developmental_screening_dataset (1).csv")

# %%
children.head(10)
# Out:
#   Child_ID  Age_Months  Gender Does child respond when called by name?  \
# 0  C000001          50  Female                                     Yes
# 1  C000002          63  Female                                     Yes
# 2  C000003          40  Female                                     Yes
# 3  C000004          26    Male                                     Yes
# 4  C000005          54  Female                               Sometimes
# 5  C000006          19  Female                               Sometimes
# 6  C000007          72  Female                                     Yes
# 7  C000008          32    Male                                     Yes
# 8  C000009          50  Female                                     Yes
# 9  C000010          69  Female                                     Yes
#
#   If not, does child react to familiar voices?  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
#
#   Can child communicate basic needs using words or gestures?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                          Sometimes
# 6                                                Yes
# 7                                          Sometimes
# 8                                                Yes
# 9                                                Yes
#
#   If not, does child attempt communication through sounds or pointing?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Can child walk without support?  \
# 0                             Yes
# 1                             Yes
# 2                             Yes
# 3                             Yes
# 4                             Yes
# 5                             Yes
# 6                             Yes
# 7                             Yes
# 8                             Yes
# 9                             Yes
#
#   If not, can child stand while holding furniture?  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
#
#   Can child climb stairs or furniture independently?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                          Sometimes
# 6                                                Yes
# 7                                                Yes
# 8                                                Yes
# 9                                                Yes
#
#   If not, can child move independently between locations?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Does child make eye contact during interaction?  \
# 0                                             Yes
# 1                                             Yes
# 2                                       Sometimes
# 3                                       Sometimes
# 4                                             Yes
# 5                                              No
# 6                                             Yes
# 7                                             Yes
# 8                                             Yes
# 9                                             Yes
#
#   If not, does child respond to smiling faces?  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                           No
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
#
#   Does child engage in play with caregivers or peers?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
# 5                                                Yes
# 6                                                Yes
# 7                                                 No
# 8                                                Yes
# 9                                                Yes
#
#   If not, does child show interest when others are playing nearby?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                Yes
# 8                                                NaN
# 9                                                NaN
#
#   Can child identify familiar people or objects?  \
# 0                                            Yes
# 1                                             No
# 2                                            Yes
# 3                                             No
# 4                                             No
# 5                                      Sometimes
# 6                                      Sometimes
# 7                                            Yes
# 8                                            Yes
# 9                                            Yes
#
#   If not, can child recognize their primary caregiver?  \
# 0                                                NaN
# 1                                                 No
# 2                                                NaN
# 3                                                Yes
# 4                                                 No
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   Can child follow age-appropriate instructions?  \
# 0                                            Yes
# 1                                            Yes
# 2                                            Yes
# 3                                      Sometimes
# 4                                            Yes
# 5                                            Yes
# 6                                            Yes
# 7                                            Yes
# 8                                            Yes
# 9                                            Yes
#
#   If not, can child follow simple one-step commands? Risk_Level
# 0                                                NaN   On Track
# 1                                                NaN      Watch
# 2                                                NaN   On Track
# 3                                                NaN      Watch
# 4                                                NaN      Watch
# 5                                                NaN  Refer Now
# 6                                                NaN   On Track
# 7                                                NaN      Watch
# 8                                                NaN   On Track
# 9                                                NaN   On Track

# %%
children.isnull().sum()
# Out:
# Child_ID                                                                    0
# Age_Months                                                                  0
# Gender                                                                      0
# Does child respond when called by name?                                     0
# If not, does child react to familiar voices?                            43967
# Can child communicate basic needs using words or gestures?                  0
# If not, does child attempt communication through sounds or pointing?    43899
# Can child walk without support?                                             0
# If not, can child stand while holding furniture?                        43987
# Can child climb stairs or furniture independently?                          0
# If not, can child move independently between locations?                 43949
# Does child make eye contact during interaction?                             0
# If not, does child respond to smiling faces?                            43931
# Does child engage in play with caregivers or peers?                         0
# If not, does child show interest when others are playing nearby?        43902
# Can child identify familiar people or objects?                              0
# If not, can child recognize their primary caregiver?                    44030
# Can child follow age-appropriate instructions?                              0
# If not, can child follow simple one-step commands?                      44147
# Risk_Level                                                                  0
# dtype: int64

# %%
children.shape
# Out:
# (50000, 20)

# %%
children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Child_ID                                                              50000 non-null  object
#  1   Age_Months                                                            50000 non-null  int64
#  2   Gender                                                                50000 non-null  object
#  3   Does child respond when called by name?                               50000 non-null  object
#  4   If not, does child react to familiar voices?                          6033 non-null   object
#  5   Can child communicate basic needs using words or gestures?            50000 non-null  object
#  6   If not, does child attempt communication through sounds or pointing?  6101 non-null   object
#  7   Can child walk without support?                                       50000 non-null  object
#  8   If not, can child stand while holding furniture?                      6013 non-null   object
#  9   Can child climb stairs or furniture independently?                    50000 non-null  object
#  10  If not, can child move independently between locations?               6051 non-null   object
#  11  Does child make eye contact during interaction?                       50000 non-null  object
#  12  If not, does child respond to smiling faces?                          6069 non-null   object
#  13  Does child engage in play with caregivers or peers?                   50000 non-null  object
#  14  If not, does child show interest when others are playing nearby?      6098 non-null   object
#  15  Can child identify familiar people or objects?                        50000 non-null  object
#  16  If not, can child recognize their primary caregiver?                  5970 non-null   object
#  17  Can child follow age-appropriate instructions?                        50000 non-null  object
#  18  If not, can child follow simple one-step commands?                    5853 non-null   object
#  19  Risk_Level                                                            50000 non-null  object
# dtypes: int64(1), object(19)
# memory usage: 7.6+ MB

# %%
children.describe()
# Out:
#          Age_Months
# count  50000.000000
# mean      42.036700
# std       17.588675
# min       12.000000
# 25%       27.000000
# 50%       42.000000
# 75%       57.000000
# max       72.000000

# %%
children.dtypes
# Out:
# Child_ID                                                                object
# Age_Months                                                               int64
# Gender                                                                  object
# Does child respond when called by name?                                 object
# If not, does child react to familiar voices?                            object
# Can child communicate basic needs using words or gestures?              object
# If not, does child attempt communication through sounds or pointing?    object
# Can child walk without support?                                         object
# If not, can child stand while holding furniture?                        object
# Can child climb stairs or furniture independently?                      object
# If not, can child move independently between locations?                 object
# Does child make eye contact during interaction?                         object
# If not, does child respond to smiling faces?                            object
# Does child engage in play with caregivers or peers?                     object
# If not, does child show interest when others are playing nearby?        object
# Can child identify familiar people or objects?                          object
# If not, can child recognize their primary caregiver?                    object
# Can child follow age-appropriate instructions?                          object
# If not, can child follow simple one-step commands?                      object
# Risk_Level                                                              object
# dtype: object

# %%
children.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %%
children=children.drop(columns=['Child_ID'])

# %%
pd.crosstab(children['Gender'],children['Can child communicate basic needs using words or gestures?'])
# Out:
# Can child communicate basic needs using words or gestures?    No  Sometimes  \
# Gender
# Female                                                      3049       3016
# Male                                                        3052       2893
#
# Can child communicate basic needs using words or gestures?    Yes
# Gender
# Female                                                      19083
# Male                                                        18907

# %%
pd.crosstab(children['Gender'],children['If not, does child attempt communication through sounds or pointing?'])
# Out:
# If not, does child attempt communication through sounds or pointing?    No  \
# Gender
# Female                                                                1384
# Male                                                                  1425
#
# If not, does child attempt communication through sounds or pointing?   Yes
# Gender
# Female                                                                1665
# Male                                                                  1627

# %%
rl= (children['Risk_Level'].value_counts() / children.shape[0])*100
rl_df=pd.DataFrame( {'count': rl}).reset_index()
plt.pie(rl_df['count'],labels=rl_df['Risk_Level'],autopct="%1.1f%%")
plt.title("Risk Level distribution")
plt.show()

# %%
age_risk = pd.crosstab(children["Age_Months"],children["Risk_Level"]) 

plt.figure(figsize=(16, 5))
age_risk.plot(
    kind="bar", stacked=True,
    color=['r','g','y'],
    figsize=(16, 5)
)
plt.title("Risk Level Distribution by Age (months)", fontweight="bold", fontsize=13)
plt.xlabel("Age (months)")
plt.ylabel("Percentage")
plt.legend(title="Risk Level",bbox_to_anchor=(1.05, 1))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Train Test Split
#
# The dataset is divided into training and testing subsets. Twenty percent of the records are reserved for model evaluation.

# %%
X=children.drop(columns=['Risk_Level'])

# %%
mapping = {
    'On Track': 0,
    'Watch': 1,
    'Refer Now': 2
}

Y = children['Risk_Level'].map(mapping)

# %%
X_train,X_test,Y_train,Y_test=train_test_split( X,Y, test_size=0.2, random_state=42,stratify=Y)

# %% [markdown]
# ## 6. Data Pipeline
#
# The preprocessing workflow includes:
#
# - Missing value imputation for follow-up questions
# - Ordinal encoding of developmental screening responses
# - One hot encoding of gender
# - Feature selection using SelectKBest
#
# Response Encoding
#
# - Yes
# - Sometimes
# - No

# %% [markdown]
#  #### Did not perform binning as Random forest automatically divides data based on age group

# %%
oe_col=[ 'Does child respond when called by name?',
       'If not, does child react to familiar voices?',
       'Can child communicate basic needs using words or gestures?',
       'If not, does child attempt communication through sounds or pointing?',
       'Can child walk without support?',
       'If not, can child stand while holding furniture?',
       'Can child climb stairs or furniture independently?',
       'If not, can child move independently between locations?',
       'Does child make eye contact during interaction?',
       'If not, does child respond to smiling faces?',
       'Does child engage in play with caregivers or peers?',
       'If not, does child show interest when others are playing nearby?',
       'Can child identify familiar people or objects?',
       'If not, can child recognize their primary caregiver?',
       'Can child follow age-appropriate instructions?',
       'If not, can child follow simple one-step commands?'
       ]

# %%
oe=OrdinalEncoder(
    categories=[
        ['Yes','Sometimes','No']]* len(oe_col),
    handle_unknown='use_encoded_value',
    unknown_value=-1)

# %%
ohe=OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# %%
si=SimpleImputer(strategy="constant",fill_value=-1)

# %%
feature=SelectKBest(score_func=f_classif,k=19)

# %%
encoding= ColumnTransformer([
    ('ordinal',Pipeline([
        ('impute',si),
        ('encode',oe)
    ]),oe_col),
    ('ohe',ohe,['Gender']),
],remainder='passthrough')

# %% [markdown]
# ## 7. Model Selection
#
# Three models trained and compared:
# 1. **Logistic Regression** - Baseline linear model
# 2. **Random Forest** - Non-linear ensemble
# 3. **XGBoost** - Gradient boosting
#
# Each model wrapped in Pipeline: Encoding -> Feature Selection -> Classifier

# %% [markdown]
# ### 7.1 Logistic Regression

# %%
lr=LogisticRegression()

# %%
pipe_lr=Pipeline([
    ('encoding',encoding),
    ('feature',feature),
    ('lr',lr)
])

# %%
pipe_lr.fit(X_train,Y_train)
# Out:
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('encoding',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(fill_value=-1,
#                                                                                  strategy='constant')),
#                                                                   ('encode',
#                                                                    OrdinalEncoder(categories=[['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes...
#                                                    'playing nearby?',
#                                                    'Can child identify '
#                                                    'familiar people or '
#                                                    'objects?',
#                                                    'If not, can child '
#                                                    'recognize their primary '
#                                                    'caregiver?',
#                                                    'Can child follow '
#                                                    'age-appropriate '
#                                                    'instructions?',
#                                                    'If not, can child follow '
#                                                    'simple one-step '
#                                                    'commands?']),
#                                                  ('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender'])])),
#                 ('feature', SelectKBest(k=19)), ('lr', LogisticRegression())])

# %%
X_train_transformed=pipe_lr.named_steps['encoding'].transform(X_train)
X_train_transformed.shape
# Out:
# (40000, 19)

# %%
X_train_features=pipe_lr.named_steps['encoding'].get_feature_names_out()
X_train_features
# Out:
# array(['ordinal__Does child respond when called by name?',
#        'ordinal__If not, does child react to familiar voices?',
#        'ordinal__Can child communicate basic needs using words or gestures?',
#        'ordinal__If not, does child attempt communication through sounds or pointing?',
#        'ordinal__Can child walk without support?',
#        'ordinal__If not, can child stand while holding furniture?',
#        'ordinal__Can child climb stairs or furniture independently?',
#        'ordinal__If not, can child move independently between locations?',
#        'ordinal__Does child make eye contact during interaction?',
#        'ordinal__If not, does child respond to smiling faces?',
#        'ordinal__Does child engage in play with caregivers or peers?',
#        'ordinal__If not, does child show interest when others are playing nearby?',
#        'ordinal__Can child identify familiar people or objects?',
#        'ordinal__If not, can child recognize their primary caregiver?',
#        'ordinal__Can child follow age-appropriate instructions?',
#        'ordinal__If not, can child follow simple one-step commands?',
#        'ohe__Gender_Female', 'ohe__Gender_Male', 'remainder__Age_Months'],
#       dtype=object)

# %%
X_train_lr=pd.DataFrame(X_train_transformed,columns=X_train_features,index=X_train.index)
X_train_lr.head()
# Out:
#        ordinal__Does child respond when called by name?  \
# 39094                                               0.0
# 32477                                               0.0
# 39767                                               0.0
# 38915                                               0.0
# 30327                                               0.0
#
#        ordinal__If not, does child react to familiar voices?  \
# 39094                                               -1.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Can child communicate basic needs using words or gestures?  \
# 39094                                                0.0
# 32477                                                0.0
# 39767                                                0.0
# 38915                                                0.0
# 30327                                                0.0
#
#        ordinal__If not, does child attempt communication through sounds or pointing?  \
# 39094                                               -1.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Can child walk without support?  \
# 39094                                       2.0
# 32477                                       0.0
# 39767                                       0.0
# 38915                                       0.0
# 30327                                       0.0
#
#        ordinal__If not, can child stand while holding furniture?  \
# 39094                                                0.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Can child climb stairs or furniture independently?  \
# 39094                                                0.0
# 32477                                                0.0
# 39767                                                0.0
# 38915                                                0.0
# 30327                                                0.0
#
#        ordinal__If not, can child move independently between locations?  \
# 39094                                               -1.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Does child make eye contact during interaction?  \
# 39094                                                0.0
# 32477                                                0.0
# 39767                                                0.0
# 38915                                                0.0
# 30327                                                0.0
#
#        ordinal__If not, does child respond to smiling faces?  \
# 39094                                               -1.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Does child engage in play with caregivers or peers?  \
# 39094                                                0.0
# 32477                                                0.0
# 39767                                                0.0
# 38915                                                0.0
# 30327                                                0.0
#
#        ordinal__If not, does child show interest when others are playing nearby?  \
# 39094                                               -1.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Can child identify familiar people or objects?  \
# 39094                                                0.0
# 32477                                                0.0
# 39767                                                1.0
# 38915                                                0.0
# 30327                                                0.0
#
#        ordinal__If not, can child recognize their primary caregiver?  \
# 39094                                               -1.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ordinal__Can child follow age-appropriate instructions?  \
# 39094                                                2.0
# 32477                                                0.0
# 39767                                                1.0
# 38915                                                0.0
# 30327                                                0.0
#
#        ordinal__If not, can child follow simple one-step commands?  \
# 39094                                                2.0
# 32477                                               -1.0
# 39767                                               -1.0
# 38915                                               -1.0
# 30327                                               -1.0
#
#        ohe__Gender_Female  ohe__Gender_Male  remainder__Age_Months
# 39094                 0.0               1.0                   55.0
# 32477                 1.0               0.0                   36.0
# 39767                 0.0               1.0                   12.0
# 38915                 1.0               0.0                   58.0
# 30327                 1.0               0.0                   63.0

# %%
y_predict_lr= pipe_lr.predict(X_test)
print("Classification Report \n", classification_report(Y_test,y_predict_lr))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      3958
#            1       0.73      0.78      0.75      3008
#            2       0.91      0.87      0.89      3034
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.85      0.84      0.85     10000

# %%
#Generating Confusion Matrix
confusion_matrix(Y_test,y_predict_lr)
# Out:
# array([[3459,  494,    5],
#        [ 400, 2344,  264],
#        [   9,  381, 2644]])

# %%
print(pipe_lr.classes_)
# Out:
# [0 1 2]

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Convert test labels to one-vs-rest binary format
Y_test_bin = label_binarize(Y_test, classes=[0, 1, 2])

# Get predicted probabilities
Y_prob = pipe_lr.predict_proba(X_test)

# Class names for the legend
class_names = ['On Track', 'Watch', 'Refer Now']

plt.figure(figsize=(7,6))

for cls in range(3):
    fpr, tpr, _ = roc_curve(Y_test_bin[:, cls], Y_prob[:, cls])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr,
        tpr,
        lw=2,
        label=f'{class_names[cls]} (AUC = {roc_auc:.3f})'
    )

# Random classifier
plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Classifier')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend(loc='lower right')

plt.show()

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(
    pipe_lr,
    X,
    Y,
    cv=5,
    scoring="accuracy",
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.figure(figsize=(8,6))

plt.scatter(train_sizes, train_mean, label="Training Accuracy")
plt.scatter(train_sizes, test_mean, label="Validation Accuracy")

plt.plot(train_sizes, train_mean)
plt.plot(train_sizes, test_mean)

plt.xlabel("Training Set Size")
plt.ylabel("Accuracy")
plt.title("Learning Curve")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\.anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### 7.2 Random Forest Model

# %%
rf=RandomForestClassifier()

# %%
pipe_rf=Pipeline( [
    ('encoding',encoding),
    ('feature',feature),
    ('rf',rf)
])

# %%
pipe_rf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('encoding',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(fill_value=-1,
#                                                                                  strategy='constant')),
#                                                                   ('encode',
#                                                                    OrdinalEncoder(categories=[['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes...
#                                                    'playing nearby?',
#                                                    'Can child identify '
#                                                    'familiar people or '
#                                                    'objects?',
#                                                    'If not, can child '
#                                                    'recognize their primary '
#                                                    'caregiver?',
#                                                    'Can child follow '
#                                                    'age-appropriate '
#                                                    'instructions?',
#                                                    'If not, can child follow '
#                                                    'simple one-step '
#                                                    'commands?']),
#                                                  ('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Gender'])])),
#                 ('feature', SelectKBest(k=19)),
#                 ('rf', RandomForestClassifier())])

# %%
pipe_rf.named_steps['encoding'].transform(X_train)
# Out:
# array([[ 0., -1.,  0., ...,  0.,  1., 55.],
#        [ 0., -1.,  0., ...,  1.,  0., 36.],
#        [ 0., -1.,  0., ...,  0.,  1., 12.],
#        ...,
#        [ 2.,  0.,  0., ...,  1.,  0., 31.],
#        [ 0., -1.,  1., ...,  1.,  0., 14.],
#        [ 0., -1.,  0., ...,  1.,  0., 32.]], shape=(40000, 19))

# %%
predict_rf=pipe_rf.predict(X_test)
print(f"Classification Report: \n {classification_report(Y_test,predict_rf)}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86      3958
#            1       0.69      0.66      0.68      3008
#            2       0.86      0.86      0.86      3034
#
#     accuracy                           0.81     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.81      0.81     10000

# %%
confusion_matrix(Y_test,xgb_predict)
# Out:
# array([[3447,  506,    5],
#        [ 393, 2301,  314],
#        [  12,  397, 2625]])

# %%
# ROC - AUC values 
y_test_bin = label_binarize(Y_test,classes=[0,1,2])
y_prob= pipe_rf.predict_proba(X_test)
class_names=['On Track','Watch','Refer now']
plt.figure(figsize=(7,8))
for cls in range(3):
    fpr,tpr,_ =roc_curve(y_test_bin[ : , cls],y_prob[:,cls])
    roc_auc=auc(fpr,tpr)
    plt.plot(fpr,tpr,lw=2,label=f'{class_names[cls]} (AUC = {roc_auc:.2f})')

plt.plot([0,1],[0,1],'k--',lw=2,label='Random Classifier')
plt.xlabel("False Positive Rate")
plt.ylabel(" True Positive Rate")
plt.title("ROC - AUC Curve : Random Forest ")
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(
    pipe_rf,
    X,
    Y,
    cv=5,
    scoring="accuracy",
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.figure(figsize=(8,6))

plt.scatter(train_sizes, train_mean, label="Training Accuracy")
plt.scatter(train_sizes, test_mean, label="Validation Accuracy")

plt.plot(train_sizes, train_mean)
plt.plot(train_sizes, test_mean)

plt.xlabel("Training Set Size")
plt.ylabel("Accuracy")
plt.title("Learning Curve")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #### 7.2.1 Hyperparameter Tuning
#
# GridSearchCV is used to identify a better set of Random Forest parameters through cross validated search.

# %%
params_grid = {
    'rf__n_estimators': [100, 200],
    'rf__max_depth': [10, None],
    'rf__min_samples_split': [ 10,20],
    'rf__max_features': ['sqrt','log2']
}

# %%
rf_grid=GridSearchCV(
    estimator=pipe_rf,
    param_grid=params_grid,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('encoding',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinal',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(fill_value=-1,
#                                                                                                         strategy='constant')),
#                                                                                          ('encode',
#                                                                                           OrdinalEncoder(categories=[['Yes',
#                                                                                                                       'Sometimes',
#                                                                                                                       'No'],
#                                                                                                                      ['Yes',
#                                                                                                                       'Sometimes',
#                                                                                                                       'No'],
#                                                                                                                      ['Yes',
#                                                                                                                       'Sometimes',
#                                                                                                                       'No'],
#                                                                                                                      ['Yes',
#                                                                                                                       'Sometimes',
#                                                                                                                       'No'],
#                                                                                                                      ['Yes',
#                                                                                                                       'Someti...
#                                                                           'can '
#                                                                           'child '
#                                                                           'follow '
#                                                                           'simple '
#                                                                           'one-step '
#                                                                           'commands?']),
#                                                                         ('ohe',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse_output=False),
#                                                                          ['Gender'])])),
#                                        ('feature', SelectKBest(k=19)),
#                                        ('rf', RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'rf__max_depth': [10, None],
#                          'rf__max_features': ['sqrt', 'log2'],
#                          'rf__min_samples_split': [10, 20],
#                          'rf__n_estimators': [100, 200]},
#              verbose=2)

# %%
predict_rf_hpt=rf_grid.predict(X_test)
print(f" Classification Report : \n {classification_report(Y_test,predict_rf_hpt)}")
# Out:
#  Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      3958
#            1       0.73      0.72      0.72      3008
#            2       0.87      0.88      0.88      3034
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.83      0.83      0.83     10000

# %%
rf_grid.best_params_
# Out:
# {'rf__max_depth': None,
#  'rf__max_features': 'sqrt',
#  'rf__min_samples_split': 20,
#  'rf__n_estimators': 100}

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(
    rf_grid,
    X,
    Y,
    cv=5,
    scoring="accuracy",
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.figure(figsize=(8,6))

plt.scatter(train_sizes, train_mean, label="Training Accuracy")
plt.scatter(train_sizes, test_mean, label="Validation Accuracy")

plt.plot(train_sizes, train_mean)
plt.plot(train_sizes, test_mean)

plt.xlabel("Training Set Size")
plt.ylabel("Accuracy")
plt.title("Learning Curve")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits

# %% [markdown]
# #### 7.3 XGBoost

# %%
xgb=XGBClassifier()

# %%
pipe_xgb=Pipeline([
    ('encoding',encoding),
    ('feature',feature),
    ('xgb',xgb)
])

# %%
pipe_xgb.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('encoding',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(fill_value=-1,
#                                                                                  strategy='constant')),
#                                                                   ('encode',
#                                                                    OrdinalEncoder(categories=[['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes',
#                                                                                                'No'],
#                                                                                               ['Yes',
#                                                                                                'Sometimes...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
xgb_predict=pipe_xgb.predict(X_test)

# %%
print("Classification Report : \n",classification_report(Y_test,xgb_predict))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      3958
#            1       0.72      0.76      0.74      3008
#            2       0.89      0.87      0.88      3034
#
#     accuracy                           0.84     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
# ROC -AUC Curve 
y_label_bin= label_binarize(Y_test,classes=[0,1,2])
y_prob= pipe_xgb.predict_proba(X_test)
class_names=['On Track','Watch','Refer Now']
plt.figure(figsize=(4,5))
for cls in range(3):
    fpr,tpr,_= roc_curve(y_label_bin[:,cls],y_prob[:,cls])
    roc_auc=auc(fpr,tpr)
    plt.plot(fpr,tpr,lw=2,label=f"{class_names[cls]}  (AUC={roc_auc:.2f})")

plt.plot([0,1],[0,1],'k--',lw=2,label="Random Classifier")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate ")
plt.title("ROC - AUC of XGBoost")
plt.legend(loc='lower right')
plt.show()

# %%
confusion_matrix(Y_test,xgb_predict)
# Out:
# array([[3447,  506,    5],
#        [ 393, 2301,  314],
#        [  12,  397, 2625]])

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(
    pipe_xgb,
    X,
    Y,
    cv=5,
    scoring="accuracy",
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.figure(figsize=(8,6))

plt.scatter(train_sizes, train_mean, label="Training Accuracy")
plt.scatter(train_sizes, test_mean, label="Validation Accuracy")

plt.plot(train_sizes, train_mean)
plt.plot(train_sizes, test_mean)

plt.xlabel("Training Set Size")
plt.ylabel("Accuracy")
plt.title("Learning Curve")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ## 8. Feature Importance

# %%
importance=pipe_rf.named_steps['rf'].feature_importances_
feature_importance=pd.DataFrame( {
    'features' : pipe_rf.named_steps['encoding'].get_feature_names_out(),
    'importance' : importance
}).sort_values(ascending=False,by='importance')
top10=feature_importance.head(10)

# %%
plt.figure(figsize=(14,8))
sns.barplot(x='importance',y='features',data=top10)
plt.show()

# %% [markdown]
# ### Key Observations
#
# - Social interaction related responses are among the strongest predictors.
# - Communication milestones contribute significantly to risk prediction.
# - Follow up responses provide additional predictive information.

# %% [markdown]
# ## 9. Exporting Pickle File

# %%
pickle.dump(pipe_lr,open('model.pkl','wb'))
